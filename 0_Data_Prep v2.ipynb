# %%
import re
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup
import pandas as pd

# %%
page_url = "https://kworb.net/spotify/"

uClient = uReq(page_url) # downloads the html page from page_url

page_soup = soup(uClient.read(), "html.parser") # parses html into a readable alphabet soup

country_soup = page_soup.find("table") # narrows html down to the country

country_soup_list = country_soup.find_all("tr") # get each row of the country soup

country_dict_links = {}

for entry in country_soup_list:
    
    country_name = entry.contents[0].string # country name
    country_links = []
    for link in entry.contents[2].find_all("a"):
        
        country_links.append(link.get('href'))
    country_dict_links[country_name] = country_links

# %%
country_dict_links
# Out:
# {'Global': ['country/global_daily.html',
#   'country/global_daily_totals.html',
#   'country/global_weekly.html',
#   'country/global_weekly_totals.html'],
#  'United States': ['country/us_daily.html',
#   'country/us_daily_totals.html',
#   'country/us_weekly.html',
#   'country/us_weekly_totals.html'],
#  'United Kingdom': ['country/gb_daily.html',
#   'country/gb_daily_totals.html',
#   'country/gb_weekly.html',
#   'country/gb_weekly_totals.html'],
#  'Andorra': ['country/ad_daily.html',
#   'country/ad_daily_totals.html',
#   'country/ad_weekly.html',
#   'country/ad_weekly_totals.html'],
#  'Argentina': ['country/ar_daily.html',
#   'country/ar_daily_totals.html',
#   'country/ar_weekly.html',
#   'country/ar_weekly_totals.html'],
#  'Australia': ['country/au_daily.html',
#   'country/au_daily_totals.html',
#   'country/au_weekly.html',
#   'country/au_weekly_totals.html'],
#  'Austria': ['country/at_daily.html',
#   'country/at_daily_totals.html',
#   'country/at_weekly.html',
#   'country/at_weekly_totals.html'],
#  'Belarus': ['country/by_daily.html',
#   'country/by_daily_totals.html',
#   'country/by_weekly.html',
#   'country/by_weekly_totals.html'],
#  'Belgium': ['country/be_daily.html',
#   'country/be_daily_totals.html',
#   'country/be_weekly.html',
#   'country/be_weekly_totals.html'],
#  'Bolivia': ['country/bo_daily.html',
#   'country/bo_daily_totals.html',
#   'country/bo_weekly.html',
#   'country/bo_weekly_totals.html'],
#  'Brazil': ['country/br_daily.html',
#   'country/br_daily_totals.html',
#   'country/br_weekly.html',
#   'country/br_weekly_totals.html'],
#  'Bulgaria': ['country/bg_daily.html',
#   'country/bg_daily_totals.html',
#   'country/bg_weekly.html',
#   'country/bg_weekly_totals.html'],
#  'Canada': ['country/ca_daily.html',
#   'country/ca_daily_totals.html',
#   'country/ca_weekly.html',
#   'country/ca_weekly_totals.html'],
#  'Chile': ['country/cl_daily.html',
#   'country/cl_daily_totals.html',
#   'country/cl_weekly.html',
#   'country/cl_weekly_totals.html'],
#  'Colombia': ['country/co_daily.html',
#   'country/co_daily_totals.html',
#   'country/co_weekly.html',
#   'country/co_weekly_totals.html'],
#  'Costa Rica': ['country/cr_daily.html',
#   'country/cr_daily_totals.html',
#   'country/cr_weekly.html',
#   'country/cr_weekly_totals.html'],
#  'Cyprus': ['country/cy_daily.html',
#   'country/cy_daily_totals.html',
#   'country/cy_weekly.html',
#   'country/cy_weekly_totals.html'],
#  'Czech Republic': ['country/cz_daily.html',
#   'country/cz_daily_totals.html',
#   'country/cz_weekly.html',
#   'country/cz_weekly_totals.html'],
#  'Denmark': ['country/dk_daily.html',
#   'country/dk_daily_totals.html',
#   'country/dk_weekly.html',
#   'country/dk_weekly_totals.html'],
#  'Dominican Republic': ['country/do_daily.html',
#   'country/do_daily_totals.html',
#   'country/do_weekly.html',
#   'country/do_weekly_totals.html'],
#  'Ecuador': ['country/ec_daily.html',
#   'country/ec_daily_totals.html',
#   'country/ec_weekly.html',
#   'country/ec_weekly_totals.html'],
#  'Egypt': ['country/eg_daily.html',
#   'country/eg_daily_totals.html',
#   'country/eg_weekly.html',
#   'country/eg_weekly_totals.html'],
#  'El Salvador': ['country/sv_daily.html',
#   'country/sv_daily_totals.html',
#   'country/sv_weekly.html',
#   'country/sv_weekly_totals.html'],
#  'Estonia': ['country/ee_daily.html',
#   'country/ee_daily_totals.html',
#   'country/ee_weekly.html',
#   'country/ee_weekly_totals.html'],
#  'Finland': ['country/fi_daily.html',
#   'country/fi_daily_totals.html',
#   'country/fi_weekly.html',
#   'country/fi_weekly_totals.html'],
#  'France': ['country/fr_daily.html',
#   'country/fr_daily_totals.html',
#   'country/fr_weekly.html',
#   'country/fr_weekly_totals.html'],
#  'Germany': ['country/de_daily.html',
#   'country/de_daily_totals.html',
#   'country/de_weekly.html',
#   'country/de_weekly_totals.html'],
#  'Greece': ['country/gr_daily.html',
#   'country/gr_daily_totals.html',
#   'country/gr_weekly.html',
#   'country/gr_weekly_totals.html'],
#  'Guatemala': ['country/gt_daily.html',
#   'country/gt_daily_totals.html',
#   'country/gt_weekly.html',
#   'country/gt_weekly_totals.html'],
#  'Honduras': ['country/hn_daily.html',
#   'country/hn_daily_totals.html',
#   'country/hn_weekly.html',
#   'country/hn_weekly_totals.html'],
#  'Hong Kong': ['country/hk_daily.html',
#   'country/hk_daily_totals.html',
#   'country/hk_weekly.html',
#   'country/hk_weekly_totals.html'],
#  'Hungary': ['country/hu_daily.html',
#   'country/hu_daily_totals.html',
#   'country/hu_weekly.html',
#   'country/hu_weekly_totals.html'],
#  'Iceland': ['country/is_daily.html',
#   'country/is_daily_totals.html',
#   'country/is_weekly.html',
#   'country/is_weekly_totals.html'],
#  'India': ['country/in_daily.html',
#   'country/in_daily_totals.html',
#   'country/in_weekly.html',
#   'country/in_weekly_totals.html'],
#  'Indonesia': ['country/id_daily.html',
#   'country/id_daily_totals.html',
#   'country/id_weekly.html',
#   'country/id_weekly_totals.html'],
#  'Ireland': ['country/ie_daily.html',
#   'country/ie_daily_totals.html',
#   'country/ie_weekly.html',
#   'country/ie_weekly_totals.html'],
#  'Israel': ['country/il_daily.html',
#   'country/il_daily_totals.html',
#   'country/il_weekly.html',
#   'country/il_weekly_totals.html'],
#  'Italy': ['country/it_daily.html',
#   'country/it_daily_totals.html',
#   'country/it_weekly.html',
#   'country/it_weekly_totals.html'],
#  'Japan': ['country/jp_daily.html',
#   'country/jp_daily_totals.html',
#   'country/jp_weekly.html',
#   'country/jp_weekly_totals.html'],
#  'Kazakhstan': ['country/kz_daily.html',
#   'country/kz_daily_totals.html',
#   'country/kz_weekly.html',
#   'country/kz_weekly_totals.html'],
#  'Latvia': ['country/lv_daily.html',
#   'country/lv_daily_totals.html',
#   'country/lv_weekly.html',
#   'country/lv_weekly_totals.html'],
#  'Lithuania': ['country/lt_daily.html',
#   'country/lt_daily_totals.html',
#   'country/lt_weekly.html',
#   'country/lt_weekly_totals.html'],
#  'Luxembourg': ['country/lu_daily.html',
#   'country/lu_daily_totals.html',
#   'country/lu_weekly.html',
#   'country/lu_weekly_totals.html'],
#  'Malaysia': ['country/my_daily.html',
#   'country/my_daily_totals.html',
#   'country/my_weekly.html',
#   'country/my_weekly_totals.html'],
#  'Malta': ['country/mt_daily.html',
#   'country/mt_daily_totals.html',
#   'country/mt_weekly.html',
#   'country/mt_weekly_totals.html'],
#  'Mexico': ['country/mx_daily.html',
#   'country/mx_daily_totals.html',
#   'country/mx_weekly.html',
#   'country/mx_weekly_totals.html'],
#  'Morocco': ['country/ma_daily.html',
#   'country/ma_daily_totals.html',
#   'country/ma_weekly.html',
#   'country/ma_weekly_totals.html'],
#  'Netherlands': ['country/nl_daily.html',
#   'country/nl_daily_totals.html',
#   'country/nl_weekly.html',
#   'country/nl_weekly_totals.html'],
#  'New Zealand': ['country/nz_daily.html',
#   'country/nz_daily_totals.html',
#   'country/nz_weekly.html',
#   'country/nz_weekly_totals.html'],
#  'Nicaragua': ['country/ni_daily.html',
#   'country/ni_daily_totals.html',
#   'country/ni_weekly.html',
#   'country/ni_weekly_totals.html'],
#  'Nigeria': ['country/ng_daily.html',
#   'country/ng_daily_totals.html',
#   'country/ng_weekly.html',
#   'country/ng_weekly_totals.html'],
#  'Norway': ['country/no_daily.html',
#   'country/no_daily_totals.html',
#   'country/no_weekly.html',
#   'country/no_weekly_totals.html'],
#  'Pakistan': ['country/pk_daily.html',
#   'country/pk_daily_totals.html',
#   'country/pk_weekly.html',
#   'country/pk_weekly_totals.html'],
#  'Panama': ['country/pa_daily.html',
#   'country/pa_daily_totals.html',
#   'country/pa_weekly.html',
#   'country/pa_weekly_totals.html'],
#  'Paraguay': ['country/py_daily.html',
#   'country/py_daily_totals.html',
#   'country/py_weekly.html',
#   'country/py_weekly_totals.html'],
#  'Peru': ['country/pe_daily.html',
#   'country/pe_daily_totals.html',
#   'country/pe_weekly.html',
#   'country/pe_weekly_totals.html'],
#  'Philippines': ['country/ph_daily.html',
#   'country/ph_daily_totals.html',
#   'country/ph_weekly.html',
#   'country/ph_weekly_totals.html'],
#  'Poland': ['country/pl_daily.html',
#   'country/pl_daily_totals.html',
#   'country/pl_weekly.html',
#   'country/pl_weekly_totals.html'],
#  'Portugal': ['country/pt_daily.html',
#   'country/pt_daily_totals.html',
#   'country/pt_weekly.html',
#   'country/pt_weekly_totals.html'],
#  'Romania': ['country/ro_daily.html',
#   'country/ro_daily_totals.html',
#   'country/ro_weekly.html',
#   'country/ro_weekly_totals.html'],
#  'Russia': ['country/ru_daily.html',
#   'country/ru_daily_totals.html',
#   'country/ru_weekly.html',
#   'country/ru_weekly_totals.html'],
#  'Saudi Arabia': ['country/sa_daily.html',
#   'country/sa_daily_totals.html',
#   'country/sa_weekly.html',
#   'country/sa_weekly_totals.html'],
#  'Singapore': ['country/sg_daily.html',
#   'country/sg_daily_totals.html',
#   'country/sg_weekly.html',
#   'country/sg_weekly_totals.html'],
#  'Slovakia': ['country/sk_daily.html',
#   'country/sk_daily_totals.html',
#   'country/sk_weekly.html',
#   'country/sk_weekly_totals.html'],
#  'South Africa': ['country/za_daily.html',
#   'country/za_daily_totals.html',
#   'country/za_weekly.html',
#   'country/za_weekly_totals.html'],
#  'South Korea': ['country/kr_daily.html',
#   'country/kr_daily_totals.html',
#   'country/kr_weekly.html',
#   'country/kr_weekly_totals.html'],
#  'Spain': ['country/es_daily.html',
#   'country/es_daily_totals.html',
#   'country/es_weekly.html',
#   'country/es_weekly_totals.html'],
#  'Sweden': ['country/se_daily.html',
#   'country/se_daily_totals.html',
#   'country/se_weekly.html',
#   'country/se_weekly_totals.html'],
#  'Switzerland': ['country/ch_daily.html',
#   'country/ch_daily_totals.html',
#   'country/ch_weekly.html',
#   'country/ch_weekly_totals.html'],
#  'Taiwan': ['country/tw_daily.html',
#   'country/tw_daily_totals.html',
#   'country/tw_weekly.html',
#   'country/tw_weekly_totals.html'],
#  'Thailand': ['country/th_daily.html',
#   'country/th_daily_totals.html',
#   'country/th_weekly.html',
#   'country/th_weekly_totals.html'],
#  'Turkey': ['country/tr_daily.html',
#   'country/tr_daily_totals.html',
#   'country/tr_weekly.html',
#   'country/tr_weekly_totals.html'],
#  'Ukraine': ['country/ua_daily.html',
#   'country/ua_daily_totals.html',
#   'country/ua_weekly.html',
#   'country/ua_weekly_totals.html'],
#  'United Arab Emirates': ['country/ae_daily.html',
#   'country/ae_daily_totals.html',
#   'country/ae_weekly.html',
#   'country/ae_weekly_totals.html'],
#  'Uruguay': ['country/uy_daily.html',
#   'country/uy_daily_totals.html',
#   'country/uy_weekly.html',
#   'country/uy_weekly_totals.html'],
#  'Venezuela': ['country/ve_daily.html',
#   'country/ve_daily_totals.html',
#   'country/ve_weekly.html',
#   'country/ve_weekly_totals.html'],
#  'Vietnam': ['country/vn_daily.html',
#   'country/vn_daily_totals.html',
#   'country/vn_weekly.html',
#   'country/vn_weekly_totals.html']}

# %%
country_top_info = {country:{"links":country_dict_links[country]} for country in country_dict_links.keys()}
# Out:
# {'Global': {'links': ['country/global_daily.html',
#    'country/global_daily_totals.html',
#    'country/global_weekly.html',
#    'country/global_weekly_totals.html']},
#  'United States': {'links': ['country/us_daily.html',
#    'country/us_daily_totals.html',
#    'country/us_weekly.html',
#    'country/us_weekly_totals.html']},
#  'United Kingdom': {'links': ['country/gb_daily.html',
#    'country/gb_daily_totals.html',
#    'country/gb_weekly.html',
#    'country/gb_weekly_totals.html']},
#  'Andorra': {'links': ['country/ad_daily.html',
#    'country/ad_daily_totals.html',
#    'country/ad_weekly.html',
#    'country/ad_weekly_totals.html']},
#  'Argentina': {'links': ['country/ar_daily.html',
#    'country/ar_daily_totals.html',
#    'country/ar_weekly.html',
#    'country/ar_weekly_totals.html']},
#  'Australia': {'links': ['country/au_daily.html',
#    'country/au_daily_totals.html',
#    'country/au_weekly.html',
#    'country/au_weekly_totals.html']},
#  'Austria': {'links': ['country/at_daily.html',
#    'country/at_daily_totals.html',
#    'country/at_weekly.html',
#    'country/at_weekly_totals.html']},
#  'Belarus': {'links': ['country/by_daily.html',
#    'country/by_daily_totals.html',
#    'country/by_weekly.html',
#    'country/by_weekly_totals.html']},
#  'Belgium': {'links': ['country/be_daily.html',
#    'country/be_daily_totals.html',
#    'country/be_weekly.html',
#    'country/be_weekly_totals.html']},
#  'Bolivia': {'links': ['country/bo_daily.html',
#    'country/bo_daily_totals.html',
#    'country/bo_weekly.html',
#    'country/bo_weekly_totals.html']},
#  'Brazil': {'links': ['country/br_daily.html',
#    'country/br_daily_totals.html',
#    'country/br_weekly.html',
#    'country/br_weekly_totals.html']},
#  'Bulgaria': {'links': ['country/bg_daily.html',
#    'country/bg_daily_totals.html',
#    'country/bg_weekly.html',
#    'country/bg_weekly_totals.html']},
#  'Canada': {'links': ['country/ca_daily.html',
#    'country/ca_daily_totals.html',
#    'country/ca_weekly.html',
#    'country/ca_weekly_totals.html']},
#  'Chile': {'links': ['country/cl_daily.html',
#    'country/cl_daily_totals.html',
#    'country/cl_weekly.html',
#    'country/cl_weekly_totals.html']},
#  'Colombia': {'links': ['country/co_daily.html',
#    'country/co_daily_totals.html',
#    'country/co_weekly.html',
#    'country/co_weekly_totals.html']},
#  'Costa Rica': {'links': ['country/cr_daily.html',
#    'country/cr_daily_totals.html',
#    'country/cr_weekly.html',
#    'country/cr_weekly_totals.html']},
#  'Cyprus': {'links': ['country/cy_daily.html',
#    'country/cy_daily_totals.html',
#    'country/cy_weekly.html',
#    'country/cy_weekly_totals.html']},
#  'Czech Republic': {'links': ['country/cz_daily.html',
#    'country/cz_daily_totals.html',
#    'country/cz_weekly.html',
#    'country/cz_weekly_totals.html']},
#  'Denmark': {'links': ['country/dk_daily.html',
#    'country/dk_daily_totals.html',
#    'country/dk_weekly.html',
#    'country/dk_weekly_totals.html']},
#  'Dominican Republic': {'links': ['country/do_daily.html',
#    'country/do_daily_totals.html',
#    'country/do_weekly.html',
#    'country/do_weekly_totals.html']},
#  'Ecuador': {'links': ['country/ec_daily.html',
#    'country/ec_daily_totals.html',
#    'country/ec_weekly.html',
#    'country/ec_weekly_totals.html']},
#  'Egypt': {'links': ['country/eg_daily.html',
#    'country/eg_daily_totals.html',
#    'country/eg_weekly.html',
#    'country/eg_weekly_totals.html']},
#  'El Salvador': {'links': ['country/sv_daily.html',
#    'country/sv_daily_totals.html',
#    'country/sv_weekly.html',
#    'country/sv_weekly_totals.html']},
#  'Estonia': {'links': ['country/ee_daily.html',
#    'country/ee_daily_totals.html',
#    'country/ee_weekly.html',
#    'country/ee_weekly_totals.html']},
#  'Finland': {'links': ['country/fi_daily.html',
#    'country/fi_daily_totals.html',
#    'country/fi_weekly.html',
#    'country/fi_weekly_totals.html']},
#  'France': {'links': ['country/fr_daily.html',
#    'country/fr_daily_totals.html',
#    'country/fr_weekly.html',
#    'country/fr_weekly_totals.html']},
#  'Germany': {'links': ['country/de_daily.html',
#    'country/de_daily_totals.html',
#    'country/de_weekly.html',
#    'country/de_weekly_totals.html']},
#  'Greece': {'links': ['country/gr_daily.html',
#    'country/gr_daily_totals.html',
#    'country/gr_weekly.html',
#    'country/gr_weekly_totals.html']},
#  'Guatemala': {'links': ['country/gt_daily.html',
#    'country/gt_daily_totals.html',
#    'country/gt_weekly.html',
#    'country/gt_weekly_totals.html']},
#  'Honduras': {'links': ['country/hn_daily.html',
#    'country/hn_daily_totals.html',
#    'country/hn_weekly.html',
#    'country/hn_weekly_totals.html']},
#  'Hong Kong': {'links': ['country/hk_daily.html',
#    'country/hk_daily_totals.html',
#    'country/hk_weekly.html',
#    'country/hk_weekly_totals.html']},
#  'Hungary': {'links': ['country/hu_daily.html',
#    'country/hu_daily_totals.html',
#    'country/hu_weekly.html',
#    'country/hu_weekly_totals.html']},
#  'Iceland': {'links': ['country/is_daily.html',
#    'country/is_daily_totals.html',
#    'country/is_weekly.html',
#    'country/is_weekly_totals.html']},
#  'India': {'links': ['country/in_daily.html',
#    'country/in_daily_totals.html',
#    'country/in_weekly.html',
#    'country/in_weekly_totals.html']},
#  'Indonesia': {'links': ['country/id_daily.html',
#    'country/id_daily_totals.html',
#    'country/id_weekly.html',
#    'country/id_weekly_totals.html']},
#  'Ireland': {'links': ['country/ie_daily.html',
#    'country/ie_daily_totals.html',
#    'country/ie_weekly.html',
#    'country/ie_weekly_totals.html']},
#  'Israel': {'links': ['country/il_daily.html',
#    'country/il_daily_totals.html',
#    'country/il_weekly.html',
#    'country/il_weekly_totals.html']},
#  'Italy': {'links': ['country/it_daily.html',
#    'country/it_daily_totals.html',
#    'country/it_weekly.html',
#    'country/it_weekly_totals.html']},
#  'Japan': {'links': ['country/jp_daily.html',
#    'country/jp_daily_totals.html',
#    'country/jp_weekly.html',
#    'country/jp_weekly_totals.html']},
#  'Kazakhstan': {'links': ['country/kz_daily.html',
#    'country/kz_daily_totals.html',
#    'country/kz_weekly.html',
#    'country/kz_weekly_totals.html']},
#  'Latvia': {'links': ['country/lv_daily.html',
#    'country/lv_daily_totals.html',
#    'country/lv_weekly.html',
#    'country/lv_weekly_totals.html']},
#  'Lithuania': {'links': ['country/lt_daily.html',
#    'country/lt_daily_totals.html',
#    'country/lt_weekly.html',
#    'country/lt_weekly_totals.html']},
#  'Luxembourg': {'links': ['country/lu_daily.html',
#    'country/lu_daily_totals.html',
#    'country/lu_weekly.html',
#    'country/lu_weekly_totals.html']},
#  'Malaysia': {'links': ['country/my_daily.html',
#    'country/my_daily_totals.html',
#    'country/my_weekly.html',
#    'country/my_weekly_totals.html']},
#  'Malta': {'links': ['country/mt_daily.html',
#    'country/mt_daily_totals.html',
#    'country/mt_weekly.html',
#    'country/mt_weekly_totals.html']},
#  'Mexico': {'links': ['country/mx_daily.html',
#    'country/mx_daily_totals.html',
#    'country/mx_weekly.html',
#    'country/mx_weekly_totals.html']},
#  'Morocco': {'links': ['country/ma_daily.html',
#    'country/ma_daily_totals.html',
#    'country/ma_weekly.html',
#    'country/ma_weekly_totals.html']},
#  'Netherlands': {'links': ['country/nl_daily.html',
#    'country/nl_daily_totals.html',
#    'country/nl_weekly.html',
#    'country/nl_weekly_totals.html']},
#  'New Zealand': {'links': ['country/nz_daily.html',
#    'country/nz_daily_totals.html',
#    'country/nz_weekly.html',
#    'country/nz_weekly_totals.html']},
#  'Nicaragua': {'links': ['country/ni_daily.html',
#    'country/ni_daily_totals.html',
#    'country/ni_weekly.html',
#    'country/ni_weekly_totals.html']},
#  'Nigeria': {'links': ['country/ng_daily.html',
#    'country/ng_daily_totals.html',
#    'country/ng_weekly.html',
#    'country/ng_weekly_totals.html']},
#  'Norway': {'links': ['country/no_daily.html',
#    'country/no_daily_totals.html',
#    'country/no_weekly.html',
#    'country/no_weekly_totals.html']},
#  'Pakistan': {'links': ['country/pk_daily.html',
#    'country/pk_daily_totals.html',
#    'country/pk_weekly.html',
#    'country/pk_weekly_totals.html']},
#  'Panama': {'links': ['country/pa_daily.html',
#    'country/pa_daily_totals.html',
#    'country/pa_weekly.html',
#    'country/pa_weekly_totals.html']},
#  'Paraguay': {'links': ['country/py_daily.html',
#    'country/py_daily_totals.html',
#    'country/py_weekly.html',
#    'country/py_weekly_totals.html']},
#  'Peru': {'links': ['country/pe_daily.html',
#    'country/pe_daily_totals.html',
#    'country/pe_weekly.html',
#    'country/pe_weekly_totals.html']},
#  'Philippines': {'links': ['country/ph_daily.html',
#    'country/ph_daily_totals.html',
#    'country/ph_weekly.html',
#    'country/ph_weekly_totals.html']},
#  'Poland': {'links': ['country/pl_daily.html',
#    'country/pl_daily_totals.html',
#    'country/pl_weekly.html',
#    'country/pl_weekly_totals.html']},
#  'Portugal': {'links': ['country/pt_daily.html',
#    'country/pt_daily_totals.html',
#    'country/pt_weekly.html',
#    'country/pt_weekly_totals.html']},
#  'Romania': {'links': ['country/ro_daily.html',
#    'country/ro_daily_totals.html',
#    'country/ro_weekly.html',
#    'country/ro_weekly_totals.html']},
#  'Russia': {'links': ['country/ru_daily.html',
#    'country/ru_daily_totals.html',
#    'country/ru_weekly.html',
#    'country/ru_weekly_totals.html']},
#  'Saudi Arabia': {'links': ['country/sa_daily.html',
#    'country/sa_daily_totals.html',
#    'country/sa_weekly.html',
#    'country/sa_weekly_totals.html']},
#  'Singapore': {'links': ['country/sg_daily.html',
#    'country/sg_daily_totals.html',
#    'country/sg_weekly.html',
#    'country/sg_weekly_totals.html']},
#  'Slovakia': {'links': ['country/sk_daily.html',
#    'country/sk_daily_totals.html',
#    'country/sk_weekly.html',
#    'country/sk_weekly_totals.html']},
#  'South Africa': {'links': ['country/za_daily.html',
#    'country/za_daily_totals.html',
#    'country/za_weekly.html',
#    'country/za_weekly_totals.html']},
#  'South Korea': {'links': ['country/kr_daily.html',
#    'country/kr_daily_totals.html',
#    'country/kr_weekly.html',
#    'country/kr_weekly_totals.html']},
#  'Spain': {'links': ['country/es_daily.html',
#    'country/es_daily_totals.html',
#    'country/es_weekly.html',
#    'country/es_weekly_totals.html']},
#  'Sweden': {'links': ['country/se_daily.html',
#    'country/se_daily_totals.html',
#    'country/se_weekly.html',
#    'country/se_weekly_totals.html']},
#  'Switzerland': {'links': ['country/ch_daily.html',
#    'country/ch_daily_totals.html',
#    'country/ch_weekly.html',
#    'country/ch_weekly_totals.html']},
#  'Taiwan': {'links': ['country/tw_daily.html',
#    'country/tw_daily_totals.html',
#    'country/tw_weekly.html',
#    'country/tw_weekly_totals.html']},
#  'Thailand': {'links': ['country/th_daily.html',
#    'country/th_daily_totals.html',
#    'country/th_weekly.html',
#    'country/th_weekly_totals.html']},
#  'Turkey': {'links': ['country/tr_daily.html',
#    'country/tr_daily_totals.html',
#    'country/tr_weekly.html',
#    'country/tr_weekly_totals.html']},
#  'Ukraine': {'links': ['country/ua_daily.html',
#    'country/ua_daily_totals.html',
#    'country/ua_weekly.html',
#    'country/ua_weekly_totals.html']},
#  'United Arab Emirates': {'links': ['country/ae_daily.html',
#    'country/ae_daily_totals.html',
#    'country/ae_weekly.html',
#    'country/ae_weekly_totals.html']},
#  'Uruguay': {'links': ['country/uy_daily.html',
#    'country/uy_daily_totals.html',
#    'country/uy_weekly.html',
#    'country/uy_weekly_totals.html']},
#  'Venezuela': {'links': ['country/ve_daily.html',
#    'country/ve_daily_totals.html',
#    'country/ve_weekly.html',
#    'country/ve_weekly_totals.html']},
#  'Vietnam': {'links': ['country/vn_daily.html',
#    'country/vn_daily_totals.html',
#    'country/vn_weekly.html',
#    'country/vn_weekly_totals.html']}}

# %%
country_top_info_df = pd.DataFrame(country_dict_links.items(), columns=['Country', 'Links'])

# %%
country_abbv = {}
for country in country_dict_links.keys():
    daily_link = country_dict_links[country][0]
    match = re.search(r'country/(\w+)_daily.html', daily_link)
    abbv = match.group(1)
    country_abbv[country] = abbv

# %%
abbv_df = pd.DataFrame(list(country_abbv.items()), columns=['Country', 'Abbreviation'])

# %%
country_top_info_df.columns
# Out:
# Index(['Country', 'Links'], dtype='object')

# %%
country_top_info_df.merge(abbv_df)
# Out:
#                  Country                                              Links  \
# 0                 Global  [country/global_daily.html, country/global_dai...
# 1          United States  [country/us_daily.html, country/us_daily_total...
# 2         United Kingdom  [country/gb_daily.html, country/gb_daily_total...
# 3                Andorra  [country/ad_daily.html, country/ad_daily_total...
# 4              Argentina  [country/ar_daily.html, country/ar_daily_total...
# ..                   ...                                                ...
# 72               Ukraine  [country/ua_daily.html, country/ua_daily_total...
# 73  United Arab Emirates  [country/ae_daily.html, country/ae_daily_total...
# 74               Uruguay  [country/uy_daily.html, country/uy_daily_total...
# 75             Venezuela  [country/ve_daily.html, country/ve_daily_total...
# 76               Vietnam  [country/vn_daily.html, country/vn_daily_total...
#
#    Abbreviation
# 0        global
# 1            us
# 2            gb
# 3            ad
# 4            ar
# ..          ...
# 72           ua
# 73           ae
# 74           uy
# 75           ve
# 76           vn
#
# [77 rows x 3 columns]

# %%
# Iterate through each row and each item in the list column
daily_paths = {}
for index, row in country_top_info_df.iterrows():
    country = row['Country']
    paths = row['Links']
    daily_paths[country] = paths

# %% [markdown]
# help

# %%
def generate_dataset(path, country):
    page_url = f"https://kworb.net/spotify/{path}"
    
    uClient = uReq(page_url) # downloads the html page from page_url

    page_soup = soup(uClient.read(), "html.parser") # parses html into a readable alphabet soup

    spotify_entry_soup = page_soup.find("table") # narrows html down to the country
    
    headings = [th.get_text() for th in spotify_entry_soup.find("tr").find_all("th")]

    datasets = []
    for row in spotify_entry_soup.find_all("tr")[1:]:
        dataset = zip(headings, (td.get_text() for td in row.find_all("td")))
        datasets.append(dataset)
        
    dataset_tuples = [list(zip(dataset)) for dataset in datasets]
    
    # Convert the data into a dictionary to handle repeated attributes
    dict_data = {}
    for sublist in dataset_tuples:
        for tup in sublist:
            attribute, value = tup[0]
            if attribute in dict_data:
                dict_data[attribute].append(value)
            else:
                dict_data[attribute] = [value]

    # Create a DataFrame from the dictionary
    df = pd.DataFrame(dict_data)
    df = df.set_index("Pos")
    
    df[['Artist', 'Title']] = df["Artist and Title"].str.split("-", 1, expand=True)
    
    df_obj = df.select_dtypes('object')
    df[df_obj.columns] = df_obj.apply(lambda x: x.str.strip())
    
    df = df.reset_index()
    
    df["Country"] = country
    
    return df

# %%
dfs = []
for country in daily_paths:
    try:
        dfs.append(generate_dataset(daily_paths[country][0], country))
    except:
        continue

# %%
len(dfs)
# Out:
# 76

# %%
dfs[0]
# Out:
#      Pos  P+                                   Artist and Title  Days   Pk  \
# 0      1  +2                    Benson Boone - Beautiful Things    22    1
# 1      2   =                                   Xavi - La Diabla    64    1
# 2      3  -2                                Tate McRae - greedy   148    1
# 3      4   =  The Weeknd - One Of The Girls (w/ JENNIE, Lily...   125    2
# 4      5   =                        Taylor Swift - Cruel Summer   369    2
# ..   ...  ..                                                ...   ...  ...
# 195  196  -5  Bad Bunny - Me Porto Bonito (w/ Chencho Corleone)   573    2
# 196  197  -1                                     Milo j - M.A.I    12  141
# 197  198  RE                             The Weeknd - The Hills  1233    3
# 198  199  RE                                    Maroon 5 - Maps   516    5
# 199  200  -1                               Taylor Swift - Karma   284    8
#
#       (x?)    Streams  Streams+        7Day       7Day+          Total  \
# 0     (x4)  5,613,842  +798,921  34,942,734    +872,488     81,671,921
# 1    (x20)  5,194,103  +225,839  35,787,503    -396,929    286,191,130
# 2    (x34)  5,101,565      -639  35,178,152    -259,951    743,490,391
# 3     (x2)  4,709,776   -76,845  33,488,250    -338,453    375,564,881
# 4    (x17)  4,658,897  +141,806  30,698,216    +272,342  1,271,909,550
# ..     ...        ...       ...         ...         ...            ...
# 195   (x5)  1,271,931   +27,364   2,516,498  +1,271,931  1,603,148,852
# 196         1,268,202   +27,843   8,881,285    -156,271     15,408,948
# 197   (x8)  1,267,948             7,417,058     -69,406  1,130,011,581
# 198         1,267,049             5,021,073     -24,774    283,949,831
# 199         1,266,712   +30,194   6,429,798  +1,266,712    488,513,945
#
#            Artist                                         Title Country
# 0    Benson Boone                              Beautiful Things  Global
# 1            Xavi                                     La Diabla  Global
# 2      Tate McRae                                        greedy  Global
# 3      The Weeknd  One Of The Girls (w/ JENNIE, Lily-Rose Depp)  Global
# 4    Taylor Swift                                  Cruel Summer  Global
# ..            ...                                           ...     ...
# 195     Bad Bunny         Me Porto Bonito (w/ Chencho Corleone)  Global
# 196        Milo j                                         M.A.I  Global
# 197    The Weeknd                                     The Hills  Global
# 198      Maroon 5                                          Maps  Global
# 199  Taylor Swift                                         Karma  Global
#
# [200 rows x 14 columns]

# %%
def export(df):
    df.to_csv

# %%
top_200_songs_by_country = pd.concat(dfs, ignore_index=True)

# %% [markdown]
# maybe add today streams and total streams

# %%
top_200_songs_by_country.to_csv("top_200_songs_by_country.csv", index=False)
